# %%
#imports
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import sklearn
from sklearn.cluster import KMeans
from statsmodels.graphics.mosaicplot import mosaic

# %%
#data load
train_df =  pd.read_csv('ctr_dataset_train.csv')
test_df = pd.read_csv('ctr_dataset_test.csv')

# %% [markdown]
# # Part 1- Explore the data

# %%
train_df.head()
# Out:
#                                   op_id   timestamp       state  \
# 0  448ed944-b0a3-4f8e-9662-fb1202e2777b  1569445326  New Jersey
# 1  3c501ca8-f771-4926-acce-d532f979b8b5  1566517297    Illinois
# 2  db342130-0f34-4d43-a72c-3c1891eade24  1566375809  California
# 3  f080c21c-7791-44c5-9429-8eb411786fe7  1568568842  California
# 4  3ca5ac37-7beb-4d2e-b0a8-662a4f9eb614  1571357999     Georgia
#
#                                         user_isp   app_id             app_cat  \
# 0                                  Comcast Cable  6rm7ag7  games - simulation
# 1                               Verizon Wireless  74193f6        games - card
# 2                                   T-Mobile USA  6549c21      games - puzzle
# 3                                   T-Mobile USA  dng7e8p             unknown
# 4  North Carolina Research and Education Network  hp3monn  games - simulation
#
#   banner_pos manufacturer device_model device_version  device_height  \
# 0  top-right      Samsung     SM-G925V          6.0.1            792
# 1      right          NaN          NaN            7.0           2560
# 2   top-left          NaN          NaN            7.0           1280
# 3       left      Samsung    SM-J700T1          7.1.1           1280
# 4   top-left     T-Mobile        5049W            7.0            720
#
#    device_width  resolution  clicked
# 0          1408        True    False
# 1          1440        True    False
# 2           720        True    False
# 3           720        True    False
# 4          1280        True     True

# %%
print(train_df.shape)
# Out:
# (2519056, 14)

# %%
label_true_per =train_df[train_df['clicked'] == True]['op_id'].count()/train_df['op_id'].count()
if label_true_per<0.5:
    print("the percentage for label True is "+ str(label_true_per) + " therefor, the data is imbalanced")
else:
    print("the percentage for label True is "+ str(label_true_per) + " therefor, the data is balanced")
# Out:
# the percentage for label True is 0.0677071093298442 therefor, the data is imbalanced

# %%
train_df.describe()
# Out:
#           timestamp  device_height  device_width
# count  2.519056e+06   2.519056e+06  2.519056e+06
# mean   1.569178e+09   1.181182e+03  1.152202e+03
# std    2.319487e+06   5.193045e+02  4.526964e+02
# min    1.564423e+09   1.400000e+01  1.400000e+01
# 25%    1.567306e+09   7.200000e+02  7.200000e+02
# 50%    1.569317e+09   1.080000e+03  1.080000e+03
# 75%    1.570937e+09   1.280000e+03  1.280000e+03
# max    1.573475e+09   3.120000e+03  3.120000e+03

# %%
train_df.isna().sum()
# Out:
# op_id                  0
# timestamp              0
# state                  0
# user_isp              32
# app_id                 0
# app_cat                0
# banner_pos             0
# manufacturer      770942
# device_model      770846
# device_version         0
# device_height          0
# device_width           0
# resolution             0
# clicked                0
# dtype: int64

# %%
train_df.nunique()
# Out:
# op_id             2519056
# timestamp         1930791
# state                  51
# user_isp             3316
# app_id              14315
# app_cat                46
# banner_pos              9
# manufacturer          251
# device_model         2256
# device_version         16
# device_height         297
# device_width          238
# resolution              1
# clicked                 2
# dtype: int64

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2519056 entries, 0 to 2519055
# Data columns (total 15 columns):
# op_id             object
# timestamp         int64
# state             object
# user_isp          object
# app_id            object
# app_cat           object
# banner_pos        object
# manufacturer      object
# device_model      object
# device_version    object
# device_height     int64
# device_width      int64
# resolution        bool
# clicked           bool
# device_diag       float64
# dtypes: bool(2), float64(1), int64(3), object(9)
# memory usage: 254.7+ MB

# %%
def show_var_ctr(df, var):
    df.groupby(var).clicked.mean().plot.bar();

# %%
def show_var(df, var):
    df.groupby('clicked')[var].value_counts().unstack(0).plot.bar();

# %%
df_train_cat = train_df[['state','app_id','app_cat','banner_pos','manufacturer','device_model','device_version','clicked']]
df_train_num =train_df[['device_height','device_width','clicked']]
df_train_time = train_df[['timestamp','clicked']]

# %%
show_var(df_train_cat, 'clicked')

# %%
#plot histogrames and bars to describe the data
def show_data(data):
    data_t= data

    names = data_t.columns.tolist()

    for i in names[:-1]:
        #remove rows without value
        data = data_t[i].dropna().sort_values(ascending  = True).to_frame()
        #describe data with objects
        if data[i].dtypes == object:
            data[i].value_counts().plot(kind='bar') 
           
        #describe data with numeric
        
        else:

            data= data.reset_index(drop=True)
            data = data[i].tolist()
            #print boxplot of the data
            print('box plot of col %s' %i)
            plt.boxplot(data)
            plt.show()
            #print hist of the data
            plt.figure(figsize=(8,6))
            plt.hist(data, bins=100, alpha=0.5)
            
        
        
        plt.title('the Frequency of values  of the col %s'%i)
        plt.xlabel('the values')
        plt.ylabel('frequency')
        plt.show()

# %% [markdown]
# # Data visualization-numeric data

# %%
#present heatmap for the corr:
sns.heatmap(df_train_num.corr(), 
        xticklabels=df_train_num.corr().columns,
        yticklabels=df_train_num.corr().columns)
plt.show()

# %%
show_data(df_train_num)
# Out:
# box plot of col device_height
# box plot of col device_width

# %%
plt.scatter(df_train_num['device_height'], df_train_num['device_width'],c=df_train_num['clicked'])
plt.xlabel('device_height')
plt.ylabel('device_width')
plt.show()

# %%
df_train_num.loc[:,'device_diag'] = np.sqrt(df_train_num.device_height^2 * df_train_num.device_width^2).round()
df_train_num.device_diag.hist(bins=20);

# %%
df_train_num.loc[:,'device_diag_cat'] =pd.cut(df_train_num['device_diag'], bins = [0,20, 40, 60,100] , right=False)
show_var_ctr(df_train_num, 'device_diag_cat');

# %% [markdown]
# # Data visualization-categorial data

# %%
show_var_ctr(df_train_cat, 'banner_pos')

# %%
plt.rcParams['font.size'] = 9.0
mosaic(train_df, ['banner_pos', 'clicked']);

# %%
print(df_train_cat['app_cat'].unique())
#df_train_cat.groupby('clicked').app_cat.value_counts().unstack(0).plot.bar()
show_var_ctr(df_train_cat, 'app_cat')
# Out:
# ['games - simulation' 'games - card' 'games - puzzle' 'unknown'
#  'games - casual' 'games - arcade' 'games - action' 'music_and_audio'
#  'games - educational' 'games - role_playing' 'personalization'
#  'games - adventure' 'games - board' 'entertainment' 'games - casino'
#  'games - strategy' 'games - word' 'games - racing' 'education'
#  'games - sports' 'productivity' 'shopping' 'social' 'libraries_and_demo'
#  'games - music' 'games - trivia' 'photography' 'food_and_drink' 'tools'
#  'art_and_design' 'auto_and_vehicles' 'video_players' 'dating' 'comics'
#  'travel_and_local' 'sports' 'lifestyle' 'books_and_reference' 'beauty'
#  'business' 'weather' 'finance' 'news_and_magazines' 'health_and_fitness'
#  'events' 'communication']

# %%
#df_train_cat.groupby('clicked').state.value_counts().unstack(0).plot.bar()
show_var_ctr(df_train_cat, 'state')

# %%
#df_train_cat.groupby('clicked').device_version.value_counts().unstack(0).plot.bar()
show_var_ctr(df_train_cat, 'device_version')

# %%
train_df.groupby(['device_width','device_height','manufacturer','device_model','device_version']).count().head()
# Out:
#                                                                      op_id  \
# device_width device_height manufacturer device_model device_version
# 14           25            Samsung      SM-G930F     6.0.1               1
# 240          432           Essential    PH-1         8.1.0               1
#                            Unihertz     Jelly Pro    7.0                 4
# 320          1152          HTC          Desire 530   6.0.1              16
# 360          640           Google       Pixel XL     7.1.1               3
#
#                                                                      timestamp  \
# device_width device_height manufacturer device_model device_version
# 14           25            Samsung      SM-G930F     6.0.1                   1
# 240          432           Essential    PH-1         8.1.0                   1
#                            Unihertz     Jelly Pro    7.0                     4
# 320          1152          HTC          Desire 530   6.0.1                  16
# 360          640           Google       Pixel XL     7.1.1                   3
#
#                                                                      state  \
# device_width device_height manufacturer device_model device_version
# 14           25            Samsung      SM-G930F     6.0.1               1
# 240          432           Essential    PH-1         8.1.0               1
#                            Unihertz     Jelly Pro    7.0                 4
# 320          1152          HTC          Desire 530   6.0.1              16
# 360          640           Google       Pixel XL     7.1.1               3
#
#                                                                      user_isp  \
# device_width device_height manufacturer device_model device_version
# 14           25            Samsung      SM-G930F     6.0.1                  1
# 240          432           Essential    PH-1         8.1.0                  1
#                            Unihertz     Jelly Pro    7.0                    4
# 320          1152          HTC          Desire 530   6.0.1                 16
# 360          640           Google       Pixel XL     7.1.1                  3
#
#                                                                      app_id  \
# device_width device_height manufacturer device_model device_version
# 14           25            Samsung      SM-G930F     6.0.1                1
# 240          432           Essential    PH-1         8.1.0                1
#                            Unihertz     Jelly Pro    7.0                  4
# 320          1152          HTC          Desire 530   6.0.1               16
# 360          640           Google       Pixel XL     7.1.1                3
#
#                                                                      app_cat  \
# device_width device_height manufacturer device_model device_version
# 14           25            Samsung      SM-G930F     6.0.1                 1
# 240          432           Essential    PH-1         8.1.0                 1
#                            Unihertz     Jelly Pro    7.0                   4
# 320          1152          HTC          Desire 530   6.0.1                16
# 360          640           Google       Pixel XL     7.1.1                 3
#
#                                                                      banner_pos  \
# device_width device_height manufacturer device_model device_version
# 14           25            Samsung      SM-G930F     6.0.1                    1
# 240          432           Essential    PH-1         8.1.0                    1
#                            Unihertz     Jelly Pro    7.0                      4
# 320          1152          HTC          Desire 530   6.0.1                   16
# 360          640           Google       Pixel XL     7.1.1                    3
#
#                                                                      resolution  \
# device_width device_height manufacturer device_model device_version
# 14           25            Samsung      SM-G930F     6.0.1                    1
# 240          432           Essential    PH-1         8.1.0                    1
#                            Unihertz     Jelly Pro    7.0                      4
# 320          1152          HTC          Desire 530   6.0.1                   16
# 360          640           Google       Pixel XL     7.1.1                    3
#
#                                                                      clicked
# device_width device_height manufacturer device_model device_version
# 14           25            Samsung      SM-G930F     6.0.1                 1
# 240          432           Essential    PH-1         8.1.0                 1
#                            Unihertz     Jelly Pro    7.0                   4
# 320          1152          HTC          Desire 530   6.0.1                16
# 360          640           Google       Pixel XL     7.1.1                 3

# %%
#fill the missing device values by the dimension and version common.
df_train_filled = train_df.groupby(['device_width','device_height','device_version']).apply(lambda x: x.fillna(x.mode().iloc[0]))

# %%
df_train_filled.count()
# Out:
# op_id             2519056
# timestamp         2519056
# state             2519056
# user_isp          2519056
# app_id            2519056
# app_cat           2519056
# banner_pos        2519056
# manufacturer      2516126
# device_model      2516126
# device_version    2519056
# device_height     2519056
# device_width      2519056
# resolution        2519056
# clicked           2519056
# dtype: int64

# %% [markdown]
# # Data visualization-time data

# %%
df_train_time.loc[:,'time'] = pd.to_datetime(df_train_time['timestamp'], unit='s')
df_train_time.loc[:,'Day_of_Week'] = df_train_time['time'].dt.weekday_name

# note monday == 0 
df_train_time.loc[:,'weekend'] = df_train_time['time'].dt.dayofweek > 4

df_train_time.loc[:,'Month'] = df_train_time['time'].dt.month_name().str[:3]
df_train_time.loc[:,'hour'] = df_train_time['time'].dt.hour
df_train_time.head()
# Out:
#     timestamp  clicked                time Day_of_Week  weekend Month  hour  \
# 0  1569445326    False 2019-09-25 21:02:06   Wednesday    False   Sep    21
# 1  1566517297    False 2019-08-22 23:41:37    Thursday    False   Aug    23
# 2  1566375809    False 2019-08-21 08:23:29   Wednesday    False   Aug     8
# 3  1568568842    False 2019-09-15 17:34:02      Sunday     True   Sep    17
# 4  1571357999     True 2019-10-18 00:19:59      Friday    False   Oct     0
#
#    device_diag
# 0    45.541190
# 1    17.944358
# 2    12.727922
# 3    12.727922
# 4    47.518417

# %%
show_var(df_train_time, 'Day_of_Week')

# %%
show_var_ctr(df_train_time, 'Day_of_Week')

# %%
show_var2(df_train_time, 'Month')

# %%
show_var_ctr(df_train_time, 'Month')

# %%
show_var(df_train_time, 'hour')

# %%
show_var_ctr(df_train_time, 'hour')

# %%
show_var_ctr(df_train_time, 'weekend')

# %%
from collections import Counter
def cumulatively_categorise(column,threshold=0.85,return_categories_list=True):
  #Find the threshold value using the percentage and number of instances in the column
    threshold_value=int(threshold*len(column))
  #Initialise an empty list for our new minimised categories
    categories_list=[]
  #Initialise a variable to calculate the sum of frequencies
    s=0
  #Create a counter dictionary of the form unique_value: frequency
    counts=Counter(column)

  #Loop through the category name and its corresponding frequency after sorting the categories by descending order of frequency
    for i,j in counts.most_common():
    #Add the frequency to the global sum
        s+=dict(counts)[i]
    #Append the category name to the list
        categories_list.append(i)
    #Check if the global sum has reached the threshold value, if so break the loop
        if s>=threshold_value:
            break
  #Append the category Other to the list
    categories_list.append('Other')

  #Replace all instances not in our new categories by Other  
    new_column=column.apply(lambda x: x if x in categories_list else 'Other')

  #Return transformed column and unique values if return_categories=True
    if(return_categories_list):
        return new_column,categories_list
  #Return only the transformed column if return_categories=False
    else:
        return new_column

# %%
#Call the function with a default threshold of 85%
transformed_column,new_category_list=cumulatively_categorise(df_train_cat['app_cat'],return_categories_list=True)
